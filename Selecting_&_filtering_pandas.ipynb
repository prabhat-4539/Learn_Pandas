# %% [markdown]
# <a href="https://colab.research.google.com/github/prabhat-4539/Learn_Pandas/blob/main/Selecting_%26_filtering_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# first I have mounted my google drive
sales = pd.read_csv('/content/drive/MyDrive/Data Science practice/Datasets/store_sales_forcasting/sales.csv')
features = pd.read_csv('/content/drive/MyDrive/Data Science practice/Datasets/store_sales_forcasting/features.csv')
stores = pd.read_csv('/content/drive/MyDrive/Data Science practice/Datasets/store_sales_forcasting/stores.csv')
# here I have created 3 dataframe using read_csv method/function.

# %%
# Selecting and filtering data

# df['col']                     # Series
# df[['col1', 'col2']]         # DataFrame

# label-based selection
# df.loc[]
# df.loc[0:2, ['name', 'salary']] ---> both 0,1,2 are included in the row selection

# position-based selection
# df.iloc[]
# df.iloc[0:2, 0:3]  ----> 2 and 3 are excluded.

# filtering (Boolean Filtering)
# df[df['salary'] > 50000]

# AND --> &
# df[(cond1) & (cond2)]
# df[(df['salary'] > 50000) & (df['city'] == 'Delhi')]

# OR --> |
# df[(cond1) | (cond2)]
# df[(df['city'] == 'Delhi') | (df['age'] < 25)]

# filtering multiple values
# df['col'].isin([...])
# df[df['city'].isin(['Delhi', 'Pune'])]

# SQL-like filtering
# df.query()
# df.query("salary > 50000 and city == 'Delhi'")

# Null Filtering
# df[df['salary'].isnull()]
# df[df['salary'].notnull()]
